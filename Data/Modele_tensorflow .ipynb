# %%
import tensorflow as tf

# %%
import pandas as pd 
import numpy as np

# %%
books = pd.read_csv("goodbooks-10k/books.csv")
books
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0           1            2767052       2767052   2792775          272
# 1           2                  3             3   4640799          491
# 2           3              41865         41865   3212258          226
# 3           4               2657          2657   3275794          487
# 4           5               4671          4671    245494         1356
# ...       ...                ...           ...       ...          ...
# 9995     9996            7130616       7130616   7392860           19
# 9996     9997             208324        208324   1084709           19
# 9997     9998              77431         77431   2393986           60
# 9998     9999            8565083       8565083  13433613            7
# 9999    10000               8914          8914     11817           31
#
#             isbn        isbn13                      authors  \
# 0      439023483  9.780439e+12              Suzanne Collins
# ...

# %%
books = books[["book_id", "original_title"]]
books
# Out:
#       book_id                                     original_title
# 0           1                                   The Hunger Games
# 1           2           Harry Potter and the Philosopher's Stone
# 2           3                                           Twilight
# 3           4                              To Kill a Mockingbird
# 4           5                                   The Great Gatsby
# ...       ...                                                ...
# 9995     9996                                         Bayou Moon
# 9996     9997                                   Means of Ascent
# 9997     9998                              The Mauritius Command
# 9998     9999  Cinderella Ate My Daughter: Dispatches from th...
# 9999    10000                                The First World War
#
# [10000 rows x 2 columns]

# %%
books["original_title"] = books["original_title"].astype("str")
# Out:
# C:\Users\Yoyo\AppData\Local\Temp/ipykernel_23356/4105598593.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books["original_title"] = books["original_title"].astype("str")

# %%
books.dtypes
# Out:
# book_id            int64
# original_title    object
# dtype: object

# %%
books_dataset = tf.data.Dataset.from_tensor_slices(dict(books))

# %%
books_dataset
# Out:
# <TensorSliceDataset shapes: {book_id: (), original_title: ()}, types: {book_id: tf.int64, original_title: tf.string}>

# %%
ratings = pd.read_csv("goodbooks-10k/ratings.csv")
ratings
# Out:
#          user_id  book_id  rating
# 0              1      258       5
# 1              2     4081       4
# 2              2      260       5
# 3              2     9296       5
# 4              2     2318       3
# ...          ...      ...     ...
# 5976474    49925      510       5
# 5976475    49925      528       4
# 5976476    49925      722       4
# 5976477    49925      949       5
# 5976478    49925     1023       4
#
# [5976479 rows x 3 columns]

# %%
ratings = ratings.merge(books, how="left", on = "book_id")

# %%
ratings["original_title"].value_counts()
# Out:
# nan                                           160910
# The Hunger Games                               22806
# Harry Potter and the Philosopher's Stone       21850
# To Kill a Mockingbird                          19088
# Twilight                                       17657
#                                                ...
# Manga Classics: Les Misérables                    48
# The Magic (The Secret #3)                         48
# Batman Chronicles: Volume 1                       45
# 進撃の巨人 悔いなき選択 1                                    41
# kindle paperwhite user's guide 2nd edition        33
# Name: original_title, Length: 9275, dtype: int64

# %%
ratings.isna().sum()
# Out:
# user_id           0
# book_id           0
# rating            0
# original_title    0
# dtype: int64

# %%
ratings.drop(ratings[ratings["original_title"] == "nan"].index, inplace=True)

# %%
ratings
# Out:
#          user_id  book_id  rating  \
# 0              1      258       5
# 2              2      260       5
# 3              2     9296       5
# 4              2     2318       3
# 5              2       26       4
# ...          ...      ...     ...
# 5976473    49925      330       5
# 5976474    49925      510       5
# 5976475    49925      528       4
# 5976476    49925      722       4
# 5976477    49925      949       5
#
#                                             original_title
# 0                                     La sombra del viento
# 2                  How to Win Friends and Influence People
# 3        Das Drama des begabten Kindes und die Suche na...
# 4        The Millionaire Next Door: The Surprising Secr...
# 5                                        The Da Vinci Code
# ...                                                    ...
# 5976473                               The Eye of the World
# 5976474                                     The Great Hunt
# ...

# %%
ratings["original_title"] = ratings["original_title"].astype("str") 
ratings["user_id"] = ratings["user_id"].astype("int32") 
ratings["book_id"] = ratings["book_id"].astype("int32") 
ratings["rating"] = ratings["rating"].astype("int32")

# %%
ratings_dataset = tf.data.Dataset.from_tensor_slices(dict(ratings))

# %%
ratings_dataset = ratings_dataset.map(lambda x: {
    "original_title": x["original_title"],
    "user_id": x["user_id"],
    "rating": x["rating"]
})

# %%
tf.random.set_seed(42)
shuffled = ratings_dataset.shuffle(100_000, seed=42, reshuffle_each_iteration=False)

train = shuffled.take(80_000)
test = shuffled.skip(80_000).take(20_000)

# %%
original_title = ratings_dataset.batch(2_000_000).map(lambda x: x["original_title"])
user_ids = ratings_dataset.batch(2_000_000).map(lambda x: x["user_id"])

unique_original_title = np.unique(np.concatenate(list(original_title)))
unique_user_ids = np.unique(np.concatenate(list(user_ids)))

# %%
type(unique_user_ids)
# Out:
# numpy.ndarray

# %%
type(unique_user_ids[0])
# Out:
# numpy.int32

# %%
unique_user_ids.shape
# Out:
# (53424,)

# %%
unique_user_ids.max()
# Out:
# 53424

# %%
unique_user_ids.min()
# Out:
# 1

# %%
unique_user_ids = np.asarray(unique_user_ids).astype(np.int32)

# %%
class RankingModel(tf.keras.Model):

    def __init__(self):
        super().__init__()
        embedding_dimension = 32

    # Compute embeddings for users.
    self.user_embeddings = tf.keras.Sequential([
      tf.keras.layers.experimental.preprocessing.StringLookup(
        vocabulary=unique_user_ids, mask_token=None),
      tf.keras.layers.Embedding(len(unique_user_ids) + 1, embedding_dimension)
    ])

    # Compute embeddings for movies.
    self.movie_embeddings = tf.keras.Sequential([
      tf.keras.layers.experimental.preprocessing.StringLookup(
        vocabulary=unique_original_titles, mask_token=None),
      tf.keras.layers.Embedding(len(unique_movie_titles) + 1, embedding_dimension)
    ])

    # Compute predictions.
    self.ratings = tf.keras.Sequential([
      # Learn multiple dense layers.
      tf.keras.layers.Dense(256, activation="relu"),
      tf.keras.layers.Dense(64, activation="relu"),
      # Make rating predictions in the final layer.
      tf.keras.layers.Dense(1)
    ])

    def call(self, inputs):

        user_id, movie_title = inputs

        user_embedding = self.user_embeddings(user_id)
        movie_embedding = self.movie_embeddings(movie_title)

        return self.ratings(tf.concat([user_embedding, movie_embedding], axis=1))
# Out:
# H:\Users\Yoan\Documents\test tensorflow\.venv\lib\site-packages\numpy\core\numeric.py:2378: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return bool(asarray(a1 == a2).all())
# H:\Users\Yoan\Documents\test tensorflow\.venv\lib\site-packages\keras\layers\preprocessing\index_lookup.py:465: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self.oov_token in tokens:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23356/2720960465.py in <module>
# ----> 1 class RankingModel(tf.keras.Model):
#       2
#       3     def __init__(self):
#       4         super().__init__()
#       5         embedding_dimension = 32
#
# ~\AppData\Local\Temp/ipykernel_23356/2720960465.py in RankingModel()
# ...
